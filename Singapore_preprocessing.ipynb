# %%
import pandas as pd

# %%
A = pd.read_csv("/content/ResaleFlatPricesBasedonApprovalDate19901999 (1).csv")
A.head()
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4  1990-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0            31.0        IMPROVED                 1977          9000
# 1            31.0        IMPROVED                 1977          6000
# 2            31.0        IMPROVED                 1977          8000
# 3            31.0        IMPROVED                 1977          6000
# 4            73.0  NEW GENERATION                 1976         47200

# %%
A.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price'],
#       dtype='object')

# %%
B = pd.read_csv("/content/ResaleFlatPricesBasedonApprovalDate2000Feb2012 (1).csv")
B.head()
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  2000-01  ANG MO KIO    3 ROOM   170  ANG MO KIO AVE 4     07 TO 09
# 1  2000-01  ANG MO KIO    3 ROOM   174  ANG MO KIO AVE 4     04 TO 06
# 2  2000-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     07 TO 09
# 3  2000-01  ANG MO KIO    3 ROOM   215  ANG MO KIO AVE 1     07 TO 09
# 4  2000-01  ANG MO KIO    3 ROOM   218  ANG MO KIO AVE 1     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0            69.0        Improved                 1986      147000.0
# 1            61.0        Improved                 1986      144000.0
# 2            73.0  New Generation                 1976      159000.0
# 3            73.0  New Generation                 1976      167000.0
# 4            67.0  New Generation                 1976      163000.0

# %%
B.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price'],
#       dtype='object')

# %%
C = pd.read_csv("/content/ResaleFlatPricesBasedonRegistrationDateFromJan2015toDec2016 (1).csv")
C.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986               70
# 1            68.0  New Generation                 1981               65
# 2            69.0  New Generation                 1980               64
# 3            68.0  New Generation                 1979               63
# 4            68.0  New Generation                 1980               64
#
#    resale_price
# 0      255000.0
# 1      275000.0
# 2      285000.0
# 3      290000.0
# 4      290000.0

# %%
C.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date',
#        'remaining_lease', 'resale_price'],
#       dtype='object')

# %%
D = pd.read_csv("/content/ResaleFlatPricesBasedonRegistrationDateFromMar2012toDec2014 (1).csv")
D.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2012-03  ANG MO KIO    2 ROOM   172   ANG MO KIO AVE 4     06 TO 10
# 1  2012-03  ANG MO KIO    2 ROOM   510   ANG MO KIO AVE 8     01 TO 05
# 2  2012-03  ANG MO KIO    3 ROOM   610   ANG MO KIO AVE 4     06 TO 10
# 3  2012-03  ANG MO KIO    3 ROOM   474  ANG MO KIO AVE 10     01 TO 05
# 4  2012-03  ANG MO KIO    3 ROOM   604   ANG MO KIO AVE 5     06 TO 10
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0            45.0        Improved                 1986      250000.0
# 1            44.0        Improved                 1980      265000.0
# 2            68.0  New Generation                 1980      315000.0
# 3            67.0  New Generation                 1984      320000.0
# 4            67.0  New Generation                 1980      321000.0

# %%
D.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price'],
#       dtype='object')

# %%
E = pd.read_csv("/content/ResaleflatpricesbasedonregistrationdatefromJan2017onwards (1).csv")
E.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date     remaining_lease  \
# 0            44.0        Improved                 1979  61 years 04 months
# 1            67.0  New Generation                 1978  60 years 07 months
# 2            67.0  New Generation                 1980  62 years 05 months
# 3            68.0  New Generation                 1980   62 years 01 month
# 4            67.0  New Generation                 1980  62 years 05 months
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0
# 3      265000.0
# ...

# %%
E.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date',
#        'remaining_lease', 'resale_price'],
#       dtype='object')

# %%
data = pd.concat([A, B, C, D, E], axis=0)
data
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...         ...         ...        ...   ...               ...          ...
# 171788  2024-01      YISHUN  EXECUTIVE   360    YISHUN RING RD     04 TO 06
# 171789  2024-01      YISHUN  EXECUTIVE   387    YISHUN RING RD     10 TO 12
# 171790  2024-01      YISHUN  EXECUTIVE   606      YISHUN ST 61     04 TO 06
# 171791  2024-01      YISHUN  EXECUTIVE   606      YISHUN ST 61     10 TO 12
# 171792  2024-01      YISHUN  EXECUTIVE   827      YISHUN ST 81     01 TO 03
#
# ...

# %%
# data.to_csv("merged_data.csv",index = False)

# %%
data
# Out:
#           month        town  flat_type block       street_name storey_range  \
# 0       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3       1990-01  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4       1990-01  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...         ...         ...        ...   ...               ...          ...
# 171788  2024-01      YISHUN  EXECUTIVE   360    YISHUN RING RD     04 TO 06
# 171789  2024-01      YISHUN  EXECUTIVE   387    YISHUN RING RD     10 TO 12
# 171790  2024-01      YISHUN  EXECUTIVE   606      YISHUN ST 61     04 TO 06
# 171791  2024-01      YISHUN  EXECUTIVE   606      YISHUN ST 61     10 TO 12
# 171792  2024-01      YISHUN  EXECUTIVE   827      YISHUN ST 81     01 TO 03
#
# ...

# %%
data.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'storey_range',
#        'floor_area_sqm', 'flat_model', 'lease_commence_date', 'resale_price',
#        'remaining_lease'],
#       dtype='object')

# %%
data["flat_model"].unique()
# Out:
# array(['IMPROVED', 'NEW GENERATION', 'MODEL A', 'STANDARD', 'SIMPLIFIED',
#        'MODEL A-MAISONETTE', 'APARTMENT', 'MAISONETTE', 'TERRACE',
#        '2-ROOM', 'IMPROVED-MAISONETTE', 'MULTI GENERATION',
#        'PREMIUM APARTMENT', 'Improved', 'New Generation', 'Model A',
#        'Standard', 'Apartment', 'Simplified', 'Model A-Maisonette',
#        'Maisonette', 'Multi Generation', 'Adjoined flat',
#        'Premium Apartment', 'Terrace', 'Improved-Maisonette',
#        'Premium Maisonette', '2-room', 'Model A2', 'Type S1', 'Type S2',
#        'DBSS', 'Premium Apartment Loft', '3Gen'], dtype=object)

# %%
data["block"].nunique()
# Out:
# 2703

# %%
import datetime

data["date_object"] = pd.to_datetime(data["month"], format='%Y-%m')

data["year"] = data["date_object"].dt.year
data["month"] = data["date_object"].dt.month

# %%
data.drop(columns = ["date_object"],inplace = True)

# %%
data
# Out:
#         month        town  flat_type block       street_name storey_range  \
# 0           1  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1           1  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2           1  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3           1  ANG MO KIO     1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4           1  ANG MO KIO     3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...       ...         ...        ...   ...               ...          ...
# 171788      1      YISHUN  EXECUTIVE   360    YISHUN RING RD     04 TO 06
# 171789      1      YISHUN  EXECUTIVE   387    YISHUN RING RD     10 TO 12
# 171790      1      YISHUN  EXECUTIVE   606      YISHUN ST 61     04 TO 06
# 171791      1      YISHUN  EXECUTIVE   606      YISHUN ST 61     10 TO 12
# 171792      1      YISHUN  EXECUTIVE   827      YISHUN ST 81     01 TO 03
#
#         floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# ...

# %%
data.rename(columns = {'flat_type' : "no_of_rooms","storey_range" : "no_of_floors"},inplace = True)

# %%
data
# Out:
#         month        town no_of_rooms block       street_name no_of_floors  \
# 0           1  ANG MO KIO      1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1           1  ANG MO KIO      1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2           1  ANG MO KIO      1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3           1  ANG MO KIO      1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4           1  ANG MO KIO      3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...       ...         ...         ...   ...               ...          ...
# 171788      1      YISHUN   EXECUTIVE   360    YISHUN RING RD     04 TO 06
# 171789      1      YISHUN   EXECUTIVE   387    YISHUN RING RD     10 TO 12
# 171790      1      YISHUN   EXECUTIVE   606      YISHUN ST 61     04 TO 06
# 171791      1      YISHUN   EXECUTIVE   606      YISHUN ST 61     10 TO 12
# 171792      1      YISHUN   EXECUTIVE   827      YISHUN ST 81     01 TO 03
#
# ...

# %%
data.rename(columns = {"flat_model":"flat_type"})
# Out:
#         month        town no_of_rooms block       street_name no_of_floors  \
# 0           1  ANG MO KIO      1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1           1  ANG MO KIO      1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2           1  ANG MO KIO      1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3           1  ANG MO KIO      1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4           1  ANG MO KIO      3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
# ...       ...         ...         ...   ...               ...          ...
# 171788      1      YISHUN   EXECUTIVE   360    YISHUN RING RD     04 TO 06
# 171789      1      YISHUN   EXECUTIVE   387    YISHUN RING RD     10 TO 12
# 171790      1      YISHUN   EXECUTIVE   606      YISHUN ST 61     04 TO 06
# 171791      1      YISHUN   EXECUTIVE   606      YISHUN ST 61     10 TO 12
# 171792      1      YISHUN   EXECUTIVE   827      YISHUN ST 81     01 TO 03
#
# ...

# %%
data.isna().sum()
# Out:
# month                       0
# town                        0
# no_of_rooms                 0
# block                       0
# street_name                 0
# no_of_floors                0
# floor_area_sqm              0
# flat_model                  0
# lease_commence_date         0
# resale_price                0
# remaining_lease        709050
# year                        0
# dtype: int64

# %%
data.drop(columns = ["remaining_lease"],inplace = True)

# %%
data.isna().sum()
# Out:
# month                  0
# town                   0
# no_of_rooms            0
# block                  0
# street_name            0
# no_of_floors           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# year                   0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# month                  0
# town                   0
# no_of_rooms            0
# block                  0
# street_name            0
# no_of_floors           0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# year                   0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 917996 entries, 0 to 171792
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                917996 non-null  int64
#  1   town                 917996 non-null  object
#  2   no_of_rooms          917996 non-null  object
#  3   block                917996 non-null  object
#  4   street_name          917996 non-null  object
#  5   no_of_floors         917996 non-null  object
#  6   floor_area_sqm       917996 non-null  float64
#  7   flat_model           917996 non-null  object
#  8   lease_commence_date  917996 non-null  int64
#  9   resale_price         917996 non-null  float64
#  10  year                 917996 non-null  int64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 84.0+ MB

# %%
data.head()
# Out:
#    month        town no_of_rooms block       street_name no_of_floors  \
# 0      1  ANG MO KIO      1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1      1  ANG MO KIO      1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2      1  ANG MO KIO      1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3      1  ANG MO KIO      1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4      1  ANG MO KIO      3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price  year
# 0            31.0        IMPROVED                 1977        9000.0  1990
# 1            31.0        IMPROVED                 1977        6000.0  1990
# 2            31.0        IMPROVED                 1977        8000.0  1990
# 3            31.0        IMPROVED                 1977        6000.0  1990
# 4            73.0  NEW GENERATION                 1976       47200.0  1990

# %%
(data["block"] == 'Object').sum()
# Out:
# 0

# %%
data[data["block"].astype(str).str.isalpha()]
# Out:
# Empty DataFrame
# Columns: [month, town, no_of_rooms, block, street_name, no_of_floors, floor_area_sqm, flat_model, lease_commence_date, resale_price, year]
# Index: []

# %%
data["block"].nunique()
# Out:
# 2703

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 917996 entries, 0 to 171792
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                917996 non-null  int64
#  1   town                 917996 non-null  object
#  2   no_of_rooms          917996 non-null  object
#  3   block                917996 non-null  object
#  4   street_name          917996 non-null  object
#  5   no_of_floors         917996 non-null  object
#  6   floor_area_sqm       917996 non-null  float64
#  7   flat_model           917996 non-null  object
#  8   lease_commence_date  917996 non-null  int64
#  9   resale_price         917996 non-null  float64
#  10  year                 917996 non-null  int64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 84.0+ MB

# %%
data['no_of_rooms'] = data['no_of_rooms'].str.strip("ROOM")

# %%
data['no_of_rooms'].unique()
# Out:
# array(['1 ', '3 ', '4 ', '5 ', '2 ', 'EXECUTIVE', 'ULTI GENERATION',
#        'ULTI-GENERATION'], dtype=object)

# %%
data['flat_model'].unique()
# Out:
# array(['IMPROVED', 'NEW GENERATION', 'MODEL A', 'STANDARD', 'SIMPLIFIED',
#        'MODEL A-MAISONETTE', 'APARTMENT', 'MAISONETTE', 'TERRACE',
#        '2-ROOM', 'IMPROVED-MAISONETTE', 'MULTI GENERATION',
#        'PREMIUM APARTMENT', 'Improved', 'New Generation', 'Model A',
#        'Standard', 'Apartment', 'Simplified', 'Model A-Maisonette',
#        'Maisonette', 'Multi Generation', 'Adjoined flat',
#        'Premium Apartment', 'Terrace', 'Improved-Maisonette',
#        'Premium Maisonette', '2-room', 'Model A2', 'Type S1', 'Type S2',
#        'DBSS', 'Premium Apartment Loft', '3Gen'], dtype=object)

# %%
data[data['no_of_rooms'] == "EXECUTIVE"].count()
# Out:
# month                  69092
# town                   69092
# no_of_rooms            69092
# block                  69092
# street_name            69092
# no_of_floors           69092
# floor_area_sqm         69092
# flat_model             69092
# lease_commence_date    69092
# resale_price           69092
# year                   69092
# dtype: int64

# %%
data[data['no_of_rooms'] == "ULTI GENERATION"].count()
# Out:
# month                  279
# town                   279
# no_of_rooms            279
# block                  279
# street_name            279
# no_of_floors           279
# floor_area_sqm         279
# flat_model             279
# lease_commence_date    279
# resale_price           279
# year                   279
# dtype: int64

# %%
data[data['no_of_rooms'] == "ULTI-GENERATION"].count()
# Out:
# month                  260
# town                   260
# no_of_rooms            260
# block                  260
# street_name            260
# no_of_floors           260
# floor_area_sqm         260
# flat_model             260
# lease_commence_date    260
# resale_price           260
# year                   260
# dtype: int64

# %%
data
# Out:
#         month        town no_of_rooms block       street_name no_of_floors  \
# 0           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     10 TO 12
# 1           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     04 TO 06
# 2           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     10 TO 12
# 3           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     07 TO 09
# 4           1  ANG MO KIO          3    216  ANG MO KIO AVE 1     04 TO 06
# ...       ...         ...         ...   ...               ...          ...
# 171788      1      YISHUN   EXECUTIVE   360    YISHUN RING RD     04 TO 06
# 171789      1      YISHUN   EXECUTIVE   387    YISHUN RING RD     10 TO 12
# 171790      1      YISHUN   EXECUTIVE   606      YISHUN ST 61     04 TO 06
# 171791      1      YISHUN   EXECUTIVE   606      YISHUN ST 61     10 TO 12
# 171792      1      YISHUN   EXECUTIVE   827      YISHUN ST 81     01 TO 03
#
# ...

# %%
# data.drop(data[data["no_of_rooms"] == 'ULTI-GENERATION'].index, inplace=True)
# data.drop(data[data["no_of_rooms"] == 'ULTI GENERATION'].index, inplace=True)

# %%
data["no_of_rooms"].unique()
# Out:
# array(['1 ', '3 ', '4 ', '5 ', '2 ', 'EXECUTIVE', 'ULTI GENERATION',
#        'ULTI-GENERATION'], dtype=object)

# %%
data["no_of_rooms"].replace({"EXECUTIVE": 6}, inplace=True)

# %%
data["no_of_rooms"].unique()
# Out:
# array(['1 ', '3 ', '4 ', '5 ', '2 ', 6, 'ULTI GENERATION',
#        'ULTI-GENERATION'], dtype=object)

# %%
# data["no_of_rooms"] = data["no_of_rooms"].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 917996 entries, 0 to 171792
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                917996 non-null  int64
#  1   town                 917996 non-null  object
#  2   no_of_rooms          917996 non-null  object
#  3   block                917996 non-null  object
#  4   street_name          917996 non-null  object
#  5   no_of_floors         917996 non-null  object
#  6   floor_area_sqm       917996 non-null  float64
#  7   flat_model           917996 non-null  object
#  8   lease_commence_date  917996 non-null  int64
#  9   resale_price         917996 non-null  float64
#  10  year                 917996 non-null  int64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 84.0+ MB

# %%
data
# Out:
#         month        town no_of_rooms block       street_name no_of_floors  \
# 0           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     10 TO 12
# 1           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     04 TO 06
# 2           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     10 TO 12
# 3           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     07 TO 09
# 4           1  ANG MO KIO          3    216  ANG MO KIO AVE 1     04 TO 06
# ...       ...         ...         ...   ...               ...          ...
# 171788      1      YISHUN           6   360    YISHUN RING RD     04 TO 06
# 171789      1      YISHUN           6   387    YISHUN RING RD     10 TO 12
# 171790      1      YISHUN           6   606      YISHUN ST 61     04 TO 06
# 171791      1      YISHUN           6   606      YISHUN ST 61     10 TO 12
# 171792      1      YISHUN           6   827      YISHUN ST 81     01 TO 03
#
# ...

# %%
data["town"].unique()
# Out:
# array(['ANG MO KIO', 'BEDOK', 'BISHAN', 'BUKIT BATOK', 'BUKIT MERAH',
#        'BUKIT TIMAH', 'CENTRAL AREA', 'CHOA CHU KANG', 'CLEMENTI',
#        'GEYLANG', 'HOUGANG', 'JURONG EAST', 'JURONG WEST',
#        'KALLANG/WHAMPOA', 'MARINE PARADE', 'QUEENSTOWN', 'SENGKANG',
#        'SERANGOON', 'TAMPINES', 'TOA PAYOH', 'WOODLANDS', 'YISHUN',
#        'LIM CHU KANG', 'SEMBAWANG', 'BUKIT PANJANG', 'PASIR RIS',
#        'PUNGGOL'], dtype=object)

# %%
unique_blocks_list = data["block"].unique().tolist()
print(unique_blocks_list)
# Out:
# ['309', '216', '211', '202', '235', '232', '308', '220', '219', '247', '320', '252', '223', '230', '329', '313', '117', '110', '343', '345', '346', '121', '129', '130', '128', '127', '126', '403', '404', '405', '417', '418', '419', '441', '442', '443', '444', '450', '435', '433', '434', '424', '425', '466', '471', '474', '570', '586', '455', '465', '463', '564', '560', '558', '559', '538', '534', '601', '603', '604', '608', '611', '505', '503', '610', '607', '524', '513', '643', '542', '548', '550', '639', '637', '330', '333', '156', '152', '178', '180', '209', '231', '254', '103', '105', '344', '324', '120', '124', '414', '438', '427', '428', '473', '573', '585', '456', '544', '640', '638', '646', '150', '179', '336', '335', '401', '439', '430', '460', '459', '716', '545', '620', '622', '259', '101', '18', '28', '29', '30', '75', '76', '501', '502', '504', '2', '20', '21', '59', '58', '55', '22', '104', '107', '69', '33', '46', '116', '115', '125', '138', '87', '100', '412', '402', 
# ...

# %%
data["street_name"].unique()
# Out:
# array(['ANG MO KIO AVE 1', 'ANG MO KIO AVE 3', 'ANG MO KIO AVE 4',
#        'ANG MO KIO AVE 10', 'ANG MO KIO AVE 5', 'ANG MO KIO AVE 8',
#        'ANG MO KIO AVE 6', 'ANG MO KIO AVE 9', 'ANG MO KIO AVE 2',
#        'BEDOK RESERVOIR RD', 'BEDOK NTH ST 3', 'BEDOK STH RD',
#        'NEW UPP CHANGI RD', 'BEDOK NTH RD', 'BEDOK STH AVE 1',
#        'CHAI CHEE RD', 'CHAI CHEE DR', 'BEDOK NTH AVE 4',
#        'BEDOK STH AVE 3', 'BEDOK STH AVE 2', 'BEDOK NTH ST 2',
#        'BEDOK NTH ST 4', 'BEDOK NTH AVE 2', 'BEDOK NTH AVE 3',
#        'BEDOK NTH AVE 1', 'BEDOK NTH ST 1', 'CHAI CHEE ST', 'SIN MING RD',
#        'SHUNFU RD', 'BT BATOK ST 11', 'BT BATOK WEST AVE 8',
#        'BT BATOK WEST AVE 6', 'BT BATOK ST 21', 'BT BATOK EAST AVE 5',
#        'BT BATOK EAST AVE 4', 'HILLVIEW AVE', 'BT BATOK CTRL',
#        'BT BATOK ST 31', 'BT BATOK EAST AVE 3', 'TAMAN HO SWEE',
#        'TELOK BLANGAH CRES', 'BEO CRES', 'TELOK BLANGAH DR', 'DEPOT RD',
# ...

# %%
data["street_name"].nunique()
# Out:
# 584

# %%
data["floor_area_sqm"].nunique()
# Out:
# 210

# %%
data["floor_area_sqm"].unique()
# Out:
# array([ 31. ,  73. ,  67. ,  82. ,  74. ,  88. ,  89. ,  83. ,  68. ,
#         75. ,  81. ,  91. ,  92. ,  97. ,  90. ,  98. ,  99. , 100. ,
#         93. , 103. , 119. , 120. , 118. , 121. , 135. , 117. ,  45. ,
#         65. ,  59. ,  70. ,  76. ,  84. , 104. , 105. , 125. , 132. ,
#        139. , 123. , 143. , 151. ,  69. , 106. , 107. , 116. , 149. ,
#        141. , 146. , 148. , 145. , 154. , 150. ,  29. ,  51. ,  61. ,
#         63. ,  64. ,  72. ,  58. ,  66. ,  60. ,  53. ,  54. ,  56. ,
#         77. , 133. , 131. , 115. ,  43. ,  38. ,  41. ,  85. , 111. ,
#        101. , 112. , 137. , 127. , 147. , 163. ,  50. ,  40. ,  60.3,
#         62. ,  55. ,  57. ,  52. ,  63.1, 102. ,  83.1, 126. , 140. ,
#        142. ,  71. , 108. , 144. ,  96. , 114. , 157. , 152. , 155. ,
#         87. , 109. , 110. ,  94. , 134. , 122. , 128. ,  78. ,  46. ,
#         42. ,  49. ,  47. ,  86. , 156. ,  79. ,  80. , 124. ,  28. ,
# ...

# %%
data["flat_model"].unique()
# Out:
# array(['IMPROVED', 'NEW GENERATION', 'MODEL A', 'STANDARD', 'SIMPLIFIED',
#        'MODEL A-MAISONETTE', 'APARTMENT', 'MAISONETTE', 'TERRACE',
#        '2-ROOM', 'IMPROVED-MAISONETTE', 'MULTI GENERATION',
#        'PREMIUM APARTMENT', 'Improved', 'New Generation', 'Model A',
#        'Standard', 'Apartment', 'Simplified', 'Model A-Maisonette',
#        'Maisonette', 'Multi Generation', 'Adjoined flat',
#        'Premium Apartment', 'Terrace', 'Improved-Maisonette',
#        'Premium Maisonette', '2-room', 'Model A2', 'Type S1', 'Type S2',
#        'DBSS', 'Premium Apartment Loft', '3Gen'], dtype=object)

# %%
data['flat_model'] = data['flat_model'].replace({'New Generation':'NEW GENERATION','Model A':'MODEL A','Standard':'STANDARD','Apartment':'APARTMENT','Terrace':'TERRACE','Improved':'IMPROVED','Model A-Maisonette':'MODEL A-MAISONETTE','Improved-Maisonette':'IMPROVED-MAISONETTE'})

# %%
data["flat_model"] = data["flat_model"].replace({'Multi Generation':'MULTI GENERATION','Maisonette':'MAISONETTE'})

# %%
data["flat_model"] = data["flat_model"].replace({'Premium Apartment':'PREMIUM APARTMENT','2-room':'2-ROOM',})

# %%
data["flat_model"].unique()
# Out:
# array(['IMPROVED', 'NEW GENERATION', 'MODEL A', 'STANDARD', 'SIMPLIFIED',
#        'MODEL A-MAISONETTE', 'APARTMENT', 'MAISONETTE', 'TERRACE',
#        '2-ROOM', 'IMPROVED-MAISONETTE', 'MULTI GENERATION',
#        'PREMIUM APARTMENT', 'Simplified', 'Adjoined flat',
#        'Premium Maisonette', 'Model A2', 'Type S1', 'Type S2', 'DBSS',
#        'Premium Apartment Loft', '3Gen'], dtype=object)

# %%
data.rename(columns = {'lease_commence_date':'lease_commence_year',"flat_model": 'flat_type'},inplace = True)

# %%
data
# Out:
#         month        town no_of_rooms block       street_name no_of_floors  \
# 0           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     10 TO 12
# 1           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     04 TO 06
# 2           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     10 TO 12
# 3           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     07 TO 09
# 4           1  ANG MO KIO          3    216  ANG MO KIO AVE 1     04 TO 06
# ...       ...         ...         ...   ...               ...          ...
# 171788      1      YISHUN           6   360    YISHUN RING RD     04 TO 06
# 171789      1      YISHUN           6   387    YISHUN RING RD     10 TO 12
# 171790      1      YISHUN           6   606      YISHUN ST 61     04 TO 06
# 171791      1      YISHUN           6   606      YISHUN ST 61     10 TO 12
# 171792      1      YISHUN           6   827      YISHUN ST 81     01 TO 03
#
# ...

# %%
data[data["flat_type"] == 'Apartment']
# Out:
# Empty DataFrame
# Columns: [month, town, no_of_rooms, block, street_name, no_of_floors, floor_area_sqm, flat_type, lease_commence_year, resale_price, year]
# Index: []

# %%
data["no_of_rooms"].unique()
# Out:
# array(['1 ', '3 ', '4 ', '5 ', '2 ', 6, 'ULTI GENERATION',
#        'ULTI-GENERATION'], dtype=object)

# %%
data["no_of_rooms"] = data["no_of_rooms"].replace({'ULTI GENERATION':'ULTI-GENERATION'})

# %%
data["no_of_rooms"].unique()
# Out:
# array(['1 ', '3 ', '4 ', '5 ', '2 ', 6, 'ULTI-GENERATION'], dtype=object)

# %%
data["no_of_rooms"] = data["no_of_rooms"].replace({'ULTI-GENERATION':'MULTI-GENERATION'})

# %%
data["no_of_rooms"].unique()
# Out:
# array(['1 ', '3 ', '4 ', '5 ', '2 ', 6, 'MULTI-GENERATION'], dtype=object)

# %%
# data["no_of_rooms"] = data["no_of_rooms"].map({'MULTI-GENERATION':7})
data["no_of_rooms"] = data["no_of_rooms"].replace({'MULTI-GENERATION': 7})

# %%
data["no_of_rooms"].unique()
# Out:
# array(['1 ', '3 ', '4 ', '5 ', '2 ', 6, 7], dtype=object)

# %%
data
# Out:
#         month        town no_of_rooms block       street_name no_of_floors  \
# 0           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     10 TO 12
# 1           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     04 TO 06
# 2           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     10 TO 12
# 3           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     07 TO 09
# 4           1  ANG MO KIO          3    216  ANG MO KIO AVE 1     04 TO 06
# ...       ...         ...         ...   ...               ...          ...
# 171788      1      YISHUN           6   360    YISHUN RING RD     04 TO 06
# 171789      1      YISHUN           6   387    YISHUN RING RD     10 TO 12
# 171790      1      YISHUN           6   606      YISHUN ST 61     04 TO 06
# 171791      1      YISHUN           6   606      YISHUN ST 61     10 TO 12
# 171792      1      YISHUN           6   827      YISHUN ST 81     01 TO 03
#
# ...

# %%
data.drop_duplicates()
# Out:
#         month        town no_of_rooms block       street_name no_of_floors  \
# 0           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     10 TO 12
# 1           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     04 TO 06
# 2           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     10 TO 12
# 3           1  ANG MO KIO          1    309  ANG MO KIO AVE 1     07 TO 09
# 4           1  ANG MO KIO          3    216  ANG MO KIO AVE 1     04 TO 06
# ...       ...         ...         ...   ...               ...          ...
# 171788      1      YISHUN           6   360    YISHUN RING RD     04 TO 06
# 171789      1      YISHUN           6   387    YISHUN RING RD     10 TO 12
# 171790      1      YISHUN           6   606      YISHUN ST 61     04 TO 06
# 171791      1      YISHUN           6   606      YISHUN ST 61     10 TO 12
# 171792      1      YISHUN           6   827      YISHUN ST 81     01 TO 03
#
# ...

# %%
data.isnull().sum()
# Out:
# month                  0
# town                   0
# no_of_rooms            0
# block                  0
# street_name            0
# no_of_floors           0
# floor_area_sqm         0
# flat_type              0
# lease_commence_year    0
# resale_price           0
# year                   0
# dtype: int64

# %%
data.isna().sum()
# Out:
# month                  0
# town                   0
# no_of_rooms            0
# block                  0
# street_name            0
# no_of_floors           0
# floor_area_sqm         0
# flat_type              0
# lease_commence_year    0
# resale_price           0
# year                   0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 917996 entries, 0 to 171792
# Data columns (total 11 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   month                917996 non-null  int64
#  1   town                 917996 non-null  object
#  2   no_of_rooms          917996 non-null  object
#  3   block                917996 non-null  object
#  4   street_name          917996 non-null  object
#  5   no_of_floors         917996 non-null  object
#  6   floor_area_sqm       917996 non-null  float64
#  7   flat_type            917996 non-null  object
#  8   lease_commence_year  917996 non-null  int64
#  9   resale_price         917996 non-null  float64
#  10  year                 917996 non-null  int64
# dtypes: float64(2), int64(3), object(6)
# memory usage: 84.0+ MB

# %%
data= data[['month', 'year', 'town', 'no_of_rooms', 'block', 'street_name', 'no_of_floors', 'floor_area_sqm', 'flat_type', 'lease_commence_year','resale_price']]

# %%
data["no_of_floors"]
# Out:
# 0         10 TO 12
# 1         04 TO 06
# 2         10 TO 12
# 3         07 TO 09
# 4         04 TO 06
#             ...
# 171788    04 TO 06
# 171789    10 TO 12
# 171790    04 TO 06
# 171791    10 TO 12
# 171792    01 TO 03
# Name: no_of_floors, Length: 917996, dtype: object

# %%
data
# Out:
#         month  year        town no_of_rooms block       street_name  \
# 0           1  1990  ANG MO KIO          1    309  ANG MO KIO AVE 1
# 1           1  1990  ANG MO KIO          1    309  ANG MO KIO AVE 1
# 2           1  1990  ANG MO KIO          1    309  ANG MO KIO AVE 1
# 3           1  1990  ANG MO KIO          1    309  ANG MO KIO AVE 1
# 4           1  1990  ANG MO KIO          3    216  ANG MO KIO AVE 1
# ...       ...   ...         ...         ...   ...               ...
# 171788      1  2024      YISHUN           6   360    YISHUN RING RD
# 171789      1  2024      YISHUN           6   387    YISHUN RING RD
# 171790      1  2024      YISHUN           6   606      YISHUN ST 61
# 171791      1  2024      YISHUN           6   606      YISHUN ST 61
# 171792      1  2024      YISHUN           6   827      YISHUN ST 81
#
#        no_of_floors  floor_area_sqm       flat_type  lease_commence_year  \
# 0          10 TO 12            31.0        IMPROVED                 1977
# ...

# %%
data["year"].unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2015, 2016, 2013, 2014, 2017, 2018, 2019, 2020, 2021, 2022,
#        2023, 2024])

# %%
data["lease_commence_year"].unique()
# Out:
# array([1977, 1976, 1978, 1979, 1984, 1980, 1985, 1981, 1982, 1986, 1972,
#        1983, 1973, 1969, 1975, 1971, 1974, 1967, 1970, 1968, 1988, 1987,
#        1989, 1990, 1992, 1993, 1994, 1991, 1995, 1996, 1997, 1998, 1999,
#        2000, 2001, 1966, 2002, 2006, 2003, 2005, 2004, 2008, 2007, 2009,
#        2010, 2012, 2011, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2022,
#        2020])

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
columns = ['no_of_rooms','floor_area_sqm','resale_price']
for i in columns:
  sns.distplot(data[i])
  plt.show()
# Out:
# <ipython-input-542-f73f0d046774>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[i])
# <ipython-input-542-f73f0d046774>:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data[i])
# <ipython-input-542-f73f0d046774>:3: UserWarning:
#
# ...

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeRegressor
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import GridSearchCV

# %%
data.to_csv('Final_data.csv',index = False)

# %%
data.columns
# Out:
# Index(['month', 'year', 'town', 'no_of_rooms', 'block', 'street_name',
#        'no_of_floors', 'floor_area_sqm', 'flat_type', 'lease_commence_year',
#        'resale_price'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
data['town'] = label_encoder.fit_transform(data['town'])
data['block'] = label_encoder.fit_transform(data['block'])
data['street_name'] = label_encoder.fit_transform(data['street_name'])
data['no_of_floors'] = label_encoder.fit_transform(data['no_of_floors'])
data['flat_type'] = label_encoder.fit_transform(data['flat_type'])

# %%
data
# Out:
#         month  year  town no_of_rooms  block  street_name  no_of_floors  \
# 0           1  1990     0          1     829           13             5
# 1           1  1990     0          1     829           13             2
# 2           1  1990     0          1     829           13             5
# 3           1  1990     0          1     829           13             4
# 4           1  1990     0          3     447           13             2
# ...       ...   ...   ...         ...    ...          ...           ...
# 171788      1  2024    26           6   1033          563             2
# 171789      1  2024    26           6   1082          563             5
# 171790      1  2024    26           6   1746          572             2
# 171791      1  2024    26           6   1746          572             5
# 171792      1  2024    26           6   2365          575             0
#
#         floor_area_sqm  flat_type  lease_commence_year  resale_price
# ...

# %%
X = data.drop(columns = ["resale_price","street_name","block",'month',"flat_type","no_of_floors"])
Y = data[["resale_price"]]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, random_state=42)

# %%
X_train.shape
# Out:
# (734396, 5)

# %%
from sklearn.ensemble import RandomForestRegressor
Model_R = RandomForestRegressor()
Model_R.fit(X_train,y_train)
y_predicted_values = Model_R.predict(X_test)
mse = mean_squared_error(y_test, y_predicted_values)
r2 = r2_score(y_test, y_predicted_values)
# AME = d2_absolute_error_score(y_test, y_predicted_values)
print('Mean Square Error is : ', mse)
print('R-square value is : ', r2)
# Out:
# <ipython-input-551-557035932017>:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   Model_R.fit(X_train,y_train)
# Mean Square Error is :  803735364.7422634
# R-square value is :  0.9715748321451512

# %%
import pickle

with open("S_Model_R.pkl", "wb") as file:
    pickle.dump(Model_R, file)

# %%
feature_importances = pd.Series(Model_R.feature_importances_,index = X_train.columns).sort_values(ascending=False)
print(feature_importances)
# Out:
# year                   0.520407
# floor_area_sqm         0.291026
# town                   0.082264
# lease_commence_year    0.056020
# no_of_rooms            0.050283
# dtype: float64

# %%
Final = data[["year","floor_area_sqm","town","lease_commence_year","no_of_rooms"]]
Final.to_csv('Final_data.csv',index = False)

# %%
# from sklearn.tree import DecisionTreeRegressor
# Model_R = DecisionTreeRegressor(max_depth=50)
# Model_R.fit(X_train,y_train)
# y_predicted_values = Model_R.predict(X_test)
# mse = mean_squared_error(y_test, y_predicted_values)
# r2 = r2_score(y_test, y_predicted_values)
# # AME = d2_absolute_error_score(y_test, y_predicted_values)
# print('Mean Square Error is : ', mse)
# print('R-square value is : ', r2)

# %%
# from sklearn.ensemble import GradientBoostingRegressor
# Model_R = GradientBoostingRegressor()
# Model_R.fit(X_train,y_train)
# y_predicted_values = Model_R.predict(X_test)
# mse = mean_squared_error(y_test, y_predicted_values)
# r2 = r2_score(y_test, y_predicted_values)
# # AME = d2_absolute_error_score(y_test, y_predicted_values)
# print('Mean Square Error is : ', mse)
# print('R-square value is : ', r2)

# %%
# from xgboost import XGBRegressor
# Model_R = XGBRegressor()
# Model_R.fit(X_train,y_train)
# y_predicted_values = Model_R.predict(X_test)
# mse = mean_squared_error(y_test, y_predicted_values)
# r2 = r2_score(y_test, y_predicted_values)
# print('Mean Square Error is : ', mse)
# print('R-square value is : ', r2)

# %%
# from sklearn.ensemble import AdaBoostRegressor
# Model_R = AdaBoostRegressor()
# Model_R.fit(X_train,y_train)
# y_predicted_values = Model_R.predict(X_test)
# mse = mean_squared_error(y_test, y_predicted_values)
# r2 = r2_score(y_test, y_predicted_values)
# # AME = d2_absolute_error_score(y_test, y_predicted_values)
# print('Mean Square Error is : ', mse)
# print('R-square value is : ', r2)

# %%
# from sklearn.ensemble import ExtraTreesRegressor
# # for i in range(10,20):
# Model_R = ExtraTreesRegressor()
# Model_R.fit(X_train,y_train)
# y_predicted_values = Model_R.predict(X_test)
# mse = mean_squared_error(y_test, y_predicted_values)
# r2 = r2_score(y_test, y_predicted_values)
# # AME = d2_absolute_error_score(y_test, y_predicted_values)
# print('Mean Square Error is : ', mse)
# print('R-square value is : ', r2)
